# %%
# Run this notebook within the hybrik environment (conda)
# !pwd
# Out:
# /home/charlie/Documents/ATPIL/PoseEstimation3d

# %%
# If directory HybrIK doesn't exist, clone it
# %cd /home/charlie/Documents/ATPIL/PoseEstimation3d
import os
if not os.path.exists('HybrIK'):
    # !git clone https://github.com/Jeff-sjtu/HybrIK.git
    # then need to change the required opencv-python version in setup.py to just 'opencv-python' potentially if next doesn't work

# %mkdir -p /home/charlie/Documents/ATPIL/PoseEstimation3d/HybrIK   
# %cd /home/charlie/Documents/ATPIL/PoseEstimation3d/HybrIK
# %pip install -e .
# Out:
# /home/charlie/Documents/ATPIL/PoseEstimation3d
# /home/charlie/Documents/ATPIL/PoseEstimation3d/HybrIK
# Obtaining file:///home/charlie/Documents/ATPIL/PoseEstimation3d/HybrIK
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from hybrik==0.2.0+9b8681d) (1.23.1)
# Requirement already satisfied: six in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from hybrik==0.2.0+9b8681d) (1.16.0)
# Collecting terminaltables (from hybrik==0.2.0+9b8681d)
#   Using cached terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: scipy in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from hybrik==0.2.0+9b8681d) (1.13.1)
# Collecting cython (from hybrik==0.2.0+9b8681d)
#   Using cached Cython-3.0.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: opencv-python in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from hybrik==0.2.0+9b8681d) (4.10.0.84)
# Collecting matplotlib (from hybrik==0.2.0+9b8681d)
#   Using cached matplotlib-3.9.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting pycocotools (from hybrik==0.2.0+9b8681d)
#   Downloading pycocotools-2.0.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from hybrik==0.2.0+9b8681d) (4.66.4)
# Collecting easydict (from hybrik==0.2.0+9b8681d)
#   Downloading easydict-1.13-py3-none-any.whl.metadata (4.2 kB)
# Collecting chumpy (from hybrik==0.2.0+9b8681d)
#   Downloading chumpy-0.70.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from hybrik==0.2.0+9b8681d) (6.0.1)
# Collecting tb-nightly (from hybrik==0.2.0+9b8681d)
#   Downloading tb_nightly-2.18.0a20240616-py3-none-any.whl.metadata (1.6 kB)
# Collecting future (from hybrik==0.2.0+9b8681d)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting ffmpeg-python (from hybrik==0.2.0+9b8681d)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting joblib (from hybrik==0.2.0+9b8681d)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->hybrik==0.2.0+9b8681d)
#   Using cached contourpy-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->hybrik==0.2.0+9b8681d)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->hybrik==0.2.0+9b8681d)
#   Using cached fonttools-4.53.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->hybrik==0.2.0+9b8681d)
#   Using cached kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from matplotlib->hybrik==0.2.0+9b8681d) (24.1)
# Requirement already satisfied: pillow>=8 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from matplotlib->hybrik==0.2.0+9b8681d) (10.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib->hybrik==0.2.0+9b8681d)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from matplotlib->hybrik==0.2.0+9b8681d) (2.9.0)
# Collecting importlib-resources>=3.2.0 (from matplotlib->hybrik==0.2.0+9b8681d)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting absl-py>=0.4 (from tb-nightly->hybrik==0.2.0+9b8681d)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tb-nightly->hybrik==0.2.0+9b8681d)
#   Downloading grpcio-1.64.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting markdown>=2.6.8 (from tb-nightly->hybrik==0.2.0+9b8681d)
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf!=4.24.0,<5.0.0,>=3.19.6 (from tb-nightly->hybrik==0.2.0+9b8681d)
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from tb-nightly->hybrik==0.2.0+9b8681d) (70.0.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tb-nightly->hybrik==0.2.0+9b8681d)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tb-nightly->hybrik==0.2.0+9b8681d)
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: zipp>=3.1.0 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->hybrik==0.2.0+9b8681d) (3.19.2)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from markdown>=2.6.8->tb-nightly->hybrik==0.2.0+9b8681d) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from werkzeug>=1.0.1->tb-nightly->hybrik==0.2.0+9b8681d) (2.1.5)
# Downloading Cython-3.0.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 57.4 MB/s eta 0:00:00a 0:00:01
# Downloading easydict-1.13-py3-none-any.whl (6.8 kB)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 18.0 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 17.2 MB/s eta 0:00:00
# Using cached matplotlib-3.9.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Downloading pycocotools-2.0.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (432 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.9/432.9 kB 16.5 MB/s eta 0:00:00
# Downloading tb_nightly-2.18.0a20240616-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 78.2 MB/s eta 0:00:00:00:010:01
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 11.8 MB/s eta 0:00:00
# Using cached contourpy-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (304 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Downloading grpcio-1.64.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 409.5 kB/s eta 0:00:0000:010:01m
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 9.3 MB/s eta 0:00:00
# Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 19.0 MB/s eta 0:00:00
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 102.0 MB/s eta 0:00:00a 0:00:01
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 25.1 MB/s eta 0:00:00
# Building wheels for collected packages: chumpy
#   Building wheel for chumpy (setup.py) ... done
#   Created wheel for chumpy: filename=chumpy-0.70-py3-none-any.whl size=58263 sha256=aa6e44f684feafbd2250fd9471a82672b9eb3058410f4ad883c8c7a359914d81
#   Stored in directory: /home/charlie/.cache/pip/wheels/71/b5/d3/bbff0d638d797944856371a4ee326f9ffb1829083a383bba77
# Successfully built chumpy
# Installing collected packages: easydict, werkzeug, terminaltables, tensorboard-data-server, pyparsing, protobuf, kiwisolver, joblib, importlib-resources, grpcio, future, fonttools, cython, cycler, contourpy, absl-py, matplotlib, markdown, ffmpeg-python, chumpy, tb-nightly, pycocotools, hybrik
#   Running setup.py develop for hybrik
# Successfully installed absl-py-2.1.0 chumpy-0.70 contourpy-1.2.1 cycler-0.12.1 cython-3.0.10 easydict-1.13 ffmpeg-python-0.2.0 fonttools-4.53.0 future-1.0.0 grpcio-1.64.1 hybrik-0.2.0+9b8681d importlib-resources-6.4.0 joblib-1.4.2 kiwisolver-1.4.5 markdown-3.6 matplotlib-3.9.0 protobuf-4.25.3 pycocotools-2.0.8 pyparsing-3.1.2 tb-nightly-2.18.0a20240616 tensorboard-data-server-0.7.2 terminaltables-3.1.10 werkzeug-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gdown --upgrade

# Following file downloads are relative to the HybrIK directory

if not os.path.exists('model_files'):
    # !gdown 'https://drive.google.com/uc?id=1un9yAGlGjDooPwlnwFpJrbGHRiLaBNzV'
    # !unzip model_files.zip
    # !rm model_files.zip
    pass

if not os.path.exists('pretrained_models/hybrikx_hrnet.pth'):
    # !mkdir -p pretrained_models
    # !gdown 'https://drive.google.com/uc?id=1bKIPD60z_Im4S3W2-rew6YtOtUGff6-v' -O pretrained_models/hybrikx_hrnet.pth
    pass

if not os.path.exists('pretrained_models/hybrik_hrnet.pth'):
    # !mkdir -p pretrained_models
    # !gdown 'https://drive.google.com/uc?id=1o3z99bebm2XImElc3XEUzTNVhQboGJE9' -O pretrained_models/hybrik_hrnet.pth
    pass

if not os.path.exists('pretrained_models/hybrikx_rle_hrnet.pth'):
    # !mkdir -p pretrained_models
    # !gdown 'https://drive.google.com/uc?id=1R0WbySXs_vceygKg_oWeLMNAZCEoCadG' -O pretrained_models/hybrikx_rle_hrnet.pth
    pass

print("*" * 80)

# update ld_library_path to include the conda environment
import os
import sys

os.environ['LD_LIBRARY_PATH'] = '/home/charlie/miniconda3/envs/hybrik/lib/usr' + os.environ.get('LD_LIBRARY_PATH', '')

# !python scripts/demo_image.py --img-dir examples --out-dir res
# Out:
# Requirement already satisfied: gdown in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from gdown) (3.15.1)
# Requirement already satisfied: requests[socks] in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from requests[socks]->gdown) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from requests[socks]->gdown) (2024.6.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/charlie/miniforge3/envs/hybrik/lib/python3.9/site-packages (from requests[socks]->gdown) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.
# Downloading...
# From (original): https://drive.google.com/uc?id=1bKIPD60z_Im4S3W2-rew6YtOtUGff6-v
# From (redirected): https://drive.google.com/uc?id=1bKIPD60z_Im4S3W2-rew6YtOtUGff6-v&confirm=t&uuid=2a652086-dbf0-41ba-81ba-e7161e2e88bd
# To: /home/charlie/Documents/ATPIL/PoseEstimation3d/HybrIK/pretrained_models/hybrikx_hrnet.pth
# 100%|████████████████████████████████████████| 374M/374M [00:22<00:00, 16.4MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1o3z99bebm2XImElc3XEUzTNVhQboGJE9
# From (redirected): https://drive.google.com/uc?id=1o3z99bebm2XImElc3XEUzTNVhQboGJE9&confirm=t&uuid=df965a33-4292-4e5d-8db9-60e03ec5e2ae
# To: /home/charlie/Documents/ATPIL/PoseEstimation3d/HybrIK/pretrained_models/hybrik_hrnet.pth
# 100%|████████████████████████████████████████| 324M/324M [00:13<00:00, 24.2MB/s]
# ********************************************************************************
# Traceback (most recent call last):
#   File "/home/charlie/Documents/ATPIL/PoseEstimation3d/HybrIK/scripts/demo_image.py", line 8, in <module>
#     from easydict import EasyDict as edict
# ModuleNotFoundError: No module named 'easydict'

# %%
# make sure ffmpeg is installed 
# sudo apt install ffmpeg
# %cd /Users/charlieturner/Documents/proj/ImitationPreprocess/PoseEstimation3d/HybrIK
# !python scripts/demo_video.py --video-name ../../data/cropped_clips/return.mp4 --out-dir ../../data/meshes --save-pk
# Out:
# /Users/charlieturner/Documents/proj/ImitationPreprocess/PoseEstimation3d/HybrIK
# /Users/charlieturner/miniforge3/envs/hybrik/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/charlieturner/miniforge3/envs/hybrik/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from ./pretrained_models/hybrik_hrnet.pth...
# ### Extract Image...
# OpenCV: FFMPEG: tag 0x34504d46/'FMP4' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x34504d46/'FMP4' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../../data/cropped_clips/return.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:03.97, start: 0.000000, bitrate: 455 kb/s
#   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 190x308 [SAR 1:1 DAR 95:154], 451 kb/s, 59 fps, 59 tbr, 15104 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x110058000] [swscaler @ 0x110068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x1180a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x108080000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x148018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x148028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x148038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x148048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x148058000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x110058000] [swscaler @ 0x148068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to '../../data/meshes/raw_images/return-%06d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 190x308 [SAR 1:1 DAR 95:154], q=2-31, 200 kb/s, 59 fps, 59 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 png
# [out#0/image2 @ 0x136f120e0] video:10961KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=  234 fps=0.0 q=-0.0 Lsize=N/A time=00:00:03.96 bitrate=N/A speed=17.2x
# 100%|█████████████████████████████████████| 377/377 [00:00<00:00, 212762.73it/s]
# ### Run Model...
# 100%|███████████████████████████████████████| 377/377 [1:00:54<00:00,  9.69s/it]
# pred_uvd
# pred_xyz_17
# pred_xyz_29
# pred_xyz_24_struct
# pred_scores
# pred_camera
# pred_betas
# pred_thetas
# pred_phi
# pred_cam_root
# transl
# transl_camsys
# bbox
# height
# width
# img_path

# %%
# Run camera calibration for the video
!
