# %%
# Run this notebook within the hybrik environment (conda)

# %%
# If directory HybrIK doesn't exist, clone it
import os
if not os.path.exists('HybrIK'):
    # !git clone https://github.com/Jeff-sjtu/HybrIK.git
    # then need to change the required opencv-python version in setup.py to just 'opencv-python' potentially if next doesn't work
        
# %cd HybrIK
# %pip install -e .
# Out:
# /home/charlie/ATPIL/PoseEstimation3d/HybrIK
# Obtaining file:///home/charlie/ATPIL/PoseEstimation3d/HybrIK
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from hybrik==0.2.0+9b8681d) (1.23.1)
# Requirement already satisfied: six in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from hybrik==0.2.0+9b8681d) (1.16.0)
# Collecting terminaltables (from hybrik==0.2.0+9b8681d)
#   Using cached terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: scipy in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from hybrik==0.2.0+9b8681d) (1.13.0)
# Collecting cython (from hybrik==0.2.0+9b8681d)
#   Using cached Cython-3.0.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: opencv-python in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from hybrik==0.2.0+9b8681d) (4.9.0.80)
# Collecting matplotlib (from hybrik==0.2.0+9b8681d)
#   Using cached matplotlib-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting pycocotools (from hybrik==0.2.0+9b8681d)
#   Using cached pycocotools-2.0.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from hybrik==0.2.0+9b8681d) (4.66.4)
# Collecting easydict (from hybrik==0.2.0+9b8681d)
#   Using cached easydict-1.13-py3-none-any.whl.metadata (4.2 kB)
# Collecting chumpy (from hybrik==0.2.0+9b8681d)
#   Using cached chumpy-0.70-py3-none-any.whl
# Requirement already satisfied: pyyaml in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from hybrik==0.2.0+9b8681d) (6.0.1)
# Collecting tb-nightly (from hybrik==0.2.0+9b8681d)
#   Downloading tb_nightly-2.17.0a20240515-py3-none-any.whl.metadata (1.6 kB)
# Collecting future (from hybrik==0.2.0+9b8681d)
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting ffmpeg-python (from hybrik==0.2.0+9b8681d)
#   Using cached ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting joblib (from hybrik==0.2.0+9b8681d)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->hybrik==0.2.0+9b8681d)
#   Using cached contourpy-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->hybrik==0.2.0+9b8681d)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->hybrik==0.2.0+9b8681d)
#   Using cached fonttools-4.51.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->hybrik==0.2.0+9b8681d)
#   Using cached kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from matplotlib->hybrik==0.2.0+9b8681d) (24.0)
# Requirement already satisfied: pillow>=8 in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from matplotlib->hybrik==0.2.0+9b8681d) (10.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib->hybrik==0.2.0+9b8681d)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from matplotlib->hybrik==0.2.0+9b8681d) (2.9.0)
# Collecting importlib-resources>=3.2.0 (from matplotlib->hybrik==0.2.0+9b8681d)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting absl-py>=0.4 (from tb-nightly->hybrik==0.2.0+9b8681d)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tb-nightly->hybrik==0.2.0+9b8681d)
#   Using cached grpcio-1.63.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting markdown>=2.6.8 (from tb-nightly->hybrik==0.2.0+9b8681d)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf!=4.24.0,<5.0.0,>=3.19.6 (from tb-nightly->hybrik==0.2.0+9b8681d)
#   Using cached protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from tb-nightly->hybrik==0.2.0+9b8681d) (69.5.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tb-nightly->hybrik==0.2.0+9b8681d)
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tb-nightly->hybrik==0.2.0+9b8681d)
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: zipp>=3.1.0 in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->hybrik==0.2.0+9b8681d) (3.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from markdown>=2.6.8->tb-nightly->hybrik==0.2.0+9b8681d) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from werkzeug>=1.0.1->tb-nightly->hybrik==0.2.0+9b8681d) (2.1.5)
# Using cached Cython-3.0.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Using cached easydict-1.13-py3-none-any.whl (6.8 kB)
# Using cached ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Using cached future-1.0.0-py3-none-any.whl (491 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached matplotlib-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Using cached pycocotools-2.0.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
# Downloading tb_nightly-2.17.0a20240515-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 4.9 MB/s eta 0:00:0000:0100:01
# Using cached terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached contourpy-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (304 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.51.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Using cached grpcio-1.63.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Using cached protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Using cached werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Installing collected packages: easydict, werkzeug, terminaltables, tensorboard-data-server, pyparsing, protobuf, kiwisolver, joblib, importlib-resources, grpcio, future, fonttools, cython, cycler, contourpy, absl-py, matplotlib, markdown, ffmpeg-python, chumpy, tb-nightly, pycocotools, hybrik
#   Running setup.py develop for hybrik
# Successfully installed absl-py-2.1.0 chumpy-0.70 contourpy-1.2.1 cycler-0.12.1 cython-3.0.10 easydict-1.13 ffmpeg-python-0.2.0 fonttools-4.51.0 future-1.0.0 grpcio-1.63.0 hybrik-0.2.0+9b8681d importlib-resources-6.4.0 joblib-1.4.2 kiwisolver-1.4.5 markdown-3.6 matplotlib-3.8.4 protobuf-4.25.3 pycocotools-2.0.7 pyparsing-3.1.2 tb-nightly-2.17.0a20240515 tensorboard-data-server-0.7.2 terminaltables-3.1.10 werkzeug-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gdown --upgrade

# Following file downloads are relative to the HybrIK directory

if not os.path.exists('model_files'):
    # !gdown 'https://drive.google.com/uc?id=1un9yAGlGjDooPwlnwFpJrbGHRiLaBNzV'
    # !unzip model_files.zip
    # !rm model_files.zip

if not os.path.exists('pretrained_models/hybrikx_hrnet.pth'):
    # !mkdir -p pretrained_models
    # !gdown 'https://drive.google.com/uc?id=1bKIPD60z_Im4S3W2-rew6YtOtUGff6-v' -O pretrained_models/hybrikx_hrnet.pth

if not os.path.exists('pretrained_models/hybrik_hrnet.pth'):
    # !mkdir -p pretrained_models
    # !gdown 'https://drive.google.com/uc?id=1o3z99bebm2XImElc3XEUzTNVhQboGJE9' -O pretrained_models/hybrik_hrnet.pth

print("*" * 80)

# update ld_library_path to include the conda environment
import os
import sys

os.environ['LD_LIBRARY_PATH'] = '/home/charlie/miniconda3/envs/hybrik/lib/usr' + os.environ.get('LD_LIBRARY_PATH', '')

# !python scripts/demo_image.py --img-dir examples --out-dir res
# Out:
# Collecting gdown
#   Using cached gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting beautifulsoup4 (from gdown)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: filelock in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from gdown) (3.14.0)
# Requirement already satisfied: requests[socks] in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from gdown) (4.66.4)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown)
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from requests[socks]->gdown) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (from requests[socks]->gdown) (1.7.1)
# Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4, gdown
# Successfully installed beautifulsoup4-4.12.3 gdown-5.2.0 soupsieve-2.5
# Note: you may need to restart the kernel to use updated packages.
# ********************************************************************************
# Requirement already satisfied: numpy==1.23.1 in /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages (1.23.1)
# Note: you may need to restart the kernel to use updated packages.
# /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /home/charlie/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|████████████████████████████████████████| 160M/160M [00:24<00:00, 6.70MB/s]
# Loading model from ./pretrained_models/hybrik_hrnet.pth...
# 100%|█████████████████████████████████████████████| 9/9 [00:14<00:00,  1.61s/it]

# %%
# display /home/charlie/ATPIL/PoseEstimation3d/HybrIK/res/000000000431.jpg

from PIL import Image
import IPython.display as display

img = Image.open('res/000000000431.jpg')

display.display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x389>

# %%
# Try with video ../../data/cropped_clips/front_backhand.mp4

# !python scripts/demo_video.py --video-name ../../data/cropped_clips/front_backhand.mp4 --out-dir ../../data/meshes --save-pk
# Out:
# /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/charlie/miniconda3/envs/hybrik/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from ./pretrained_models/hybrik_hrnet.pth...
# ### Extract Image...
# OpenCV: FFMPEG: tag 0x34504d46/'FMP4' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x34504d46/'FMP4' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../../data/cropped_clips/front_backhand.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:02.42, start: 0.000000, bitrate: 193 kb/s
#   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 96x168 [SAR 1:1 DAR 4:7], 188 kb/s, 59 fps, 59 tbr, 15104 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '../../data/meshes/raw_images/front_backhand-%06d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 96x168 [SAR 1:1 DAR 4:7], q=2-31, 200 kb/s, 59 fps, 59 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 png
# [out#0/image2 @ 0x57334145d080] video:2544kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=  143 fps=0.0 q=-0.0 Lsize=N/A time=00:00:02.40 bitrate=N/A speed=30.8x
# 100%|█████████████████████████████████████| 143/143 [00:00<00:00, 139777.55it/s]
# ### Run Model...
# 100%|█████████████████████████████████████████| 143/143 [02:20<00:00,  1.02it/s]
# pred_uvd
# pred_xyz_17
# pred_xyz_29
# pred_xyz_24_struct
# pred_scores
# pred_camera
# pred_betas
# pred_thetas
# pred_phi
# pred_cam_root
# transl
# transl_camsys
# bbox
# height
# width
# img_path
